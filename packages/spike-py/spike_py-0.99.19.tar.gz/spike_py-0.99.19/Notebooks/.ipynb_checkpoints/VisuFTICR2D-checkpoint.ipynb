# %% [markdown]
# ### Initialization of the environment
# the following cell should be run only once, at the beginning of the processing

# %%
from importlib import reload

# %%
# %matplotlib notebook
from __future__ import print_function, division
import matplotlib as mpl
# matplotlib.use('nbagg') 
import matplotlib.pyplot as plt
import spike
from spike.Interactive import INTER as I
from spike.Interactive import FTICR2D_INTER as I2D
mpl.rcParams['figure.figsize'] = [10.0, 10.0]

# %% [raw]
# #import matplotlib as mpl
# mpl.rcParams['figure.figsize'] = [10.0, 10.0]
# #%matplotlib notebook
# from bokeh.layouts import layout
# from bokeh.models import CustomJS, Slider, ColumnDataSource, WidgetBox
# from bokeh.plotting import figure, output_notebook, show
# from bokeh.embed import components,file_html
# from bokeh.resources import CDN
# output_notebook()

# %% [markdown]
# ### Choose the file
# Use `FileChooser()` to choose a file on your disk - The optional `base` argument, starts the exploration on a given location.
#
# 2D processed files are `*.msh5` files.

# %%
reload(I)
FC = I.FileChooser(base='/DATA/', filetype='*.msh5', mode='r')

# %%
name='/DATA/pour Florence/yeast_extract_p9kk_dn200_small_mr.msh5'

# %%
reload(I2D)
D = I2D.MR(FC.file)
# Out:
# 2D data-set
# Axis F1 :FT-ICR report axis at 500.000000 kHz,  4096 real points,  from physical mz =  328.209   to m/z = 3000.000  R max (M=400) = 3773
# Axis F2: FT-ICR report axis at 1250.000000 kHz,  262144 real points,  from physical mz =  147.411   to m/z = 3000.000  R max (M=400) = 96608
# data-set is real
# ...
# multiresolution data:
# #: Size
# 1: 4096 x 262144 : 1024 Mpix
# 2: 1024 x 65536 : 64 Mpix
# 3: 1024 x 16384 : 16 Mpix
# 4: 1024 x 4096 : 4 Mpix
# 5: 1024 x 1024 : 1 Mpix

# %%
reload(I2D)
DI = I2D.MR_interact(FC.file, report=False, show=False)
DI._zoom = (330, 700, 150, 1200) #  you can decide the initial zoom before opening
DI.show()
# Out:
# ...
# <img src="data:image/png;base64,..." width="573.75">

# %%
D.data[-1].display(zoom=(330, 700, 150, 1200), scale=20);

# %%
STOP

# %%
reload(VI)
DI = VI.MR_interact(name, report=False)

# %%
STOP

# %%
DI._zoom = (330, 1000, 330,1000)

# %%
import matplotlib.pyplot as plt

# %%
fg,ax = plt.subplots()
DI.data[-1].display(zoom=DI._zoom, figure=ax)

# %%
ax.clear()

# %%
DI.display(zoom=((440,510),(440,510)), scale=3);

# %%
STOP

# %%
print("( %s ) : %.f x %.f"%(DI.zoom, DI._zoom[1]-DI._zoom[0], DI._zoom[3]-DI._zoom[2] ))
for i in range(1):
    DI.zoom_in(factor=1.2)
    print("( %s ) : %.f x %.f"%(DI.zoom, DI._zoom[1]-DI._zoom[0], DI._zoom[3]-DI._zoom[2] ))
print("===============")
DI.up()
print("( %s ) : %.f x %.f"%(DI.zoom, DI._zoom[1]-DI._zoom[0], DI._zoom[3]-DI._zoom[2] ))
DI.left()
print("( %s ) : %.f x %.f"%(DI.zoom, DI._zoom[1]-DI._zoom[0], DI._zoom[3]-DI._zoom[2] ))
DI.right()
print("( %s ) : %.f x %.f"%(DI.zoom, DI._zoom[1]-DI._zoom[0], DI._zoom[3]-DI._zoom[2] ))
DI.down()
print("( %s ) : %.f x %.f"%(DI.zoom, DI._zoom[1]-DI._zoom[0], DI._zoom[3]-DI._zoom[2] ))
print("===============")
for i in range(1):
    print("( %s ) : %.f x %.f"%(DI.zoom, DI._zoom[1]-DI._zoom[0], DI._zoom[3]-DI._zoom[2] ))
    DI.zoom_out(factor=1.2)
print("( %s ) : %.f x %.f"%(DI.zoom, DI._zoom[1]-DI._zoom[0], DI._zoom[3]-DI._zoom[2] ))

# %%
from ipywidgets import interact, interactive, fixed, interact_manual, HBox, VBox
import ipywidgets as widgets
from IPython.display import display
# REACTIVE modify callback behaviour
# True is good for inline mode / False is better for notebook mode
REACTIVE = True

class Show(object):
    """
    An interactive display, 1D or 2D
        Show(spec)

    best when in %matplotlib inline

    """
    def __init__(self, data):
        self.data = data
        self.scale = widgets.FloatSlider(min=1, max=100, step=0.5,
                             continuous_update=REACTIVE)
        self.done = widgets.Button(description="Done")
        self.done.on_click(self.on_done)
        interact(self.show, scale=self.scale)
        display(self.done)
    def on_done(self, b):
        for w in [self.scale, self.done]:
            w.close()
    def show(self, scale, z1=0, z2=10):
        if self.data.dim == 1:
            self.data.display(scale=scale, zoom=[200,400,200,400]);
        else:
            self.data.display(scale=scale);

# %%
Show(D)

# %%
D.display((400,750,700,1300), scale=4)

# %%
D.display((500,700,700,900), scale=10)

# %%
D.display((610,650,820,840), scale=10)

# %%
D.display((700,800,1000,1200), scale=10)

# %%
D.display((700,800,1350,1400), scale=10)

# %%
d = D.data[1]
d.axis2.lowmass

# %%
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual, HBox, VBox, HTML

# %%
zb = widgets.BoundedFloatText(
    value=7.5,
    min=0,
    max=10.0,
    step=0.1,
    description='Text:'
)
def func(change):
    print(change['old'])
    print(change['new'])
def zzb(b):
    print('new:',b.value)
zb.observe(func)
display(zb)

# %%
zb.value+1

# %%
zb.value = 'coucou'
